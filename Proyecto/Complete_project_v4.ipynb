# %% [markdown]
# <h1 style="text-align: center">PROYECTO FINAL TALENTO TECH CICLO EXPLORADOR</h1>
# Fecha: Noviembre y Diciembre de 2024
#
# ### Integrantes
# - Jose Manuel Villa Romero
# - Sebastian Vasquez Grajales
# - Juan Camilo Castaño Marulanda
#
# ## Fundamentación teórica
# ### 1. Fases del ciclo de vida de un proyecto de machine learning
# El ciclo de vida de una aplicación de aprendizaje de máquina comienza con la identificación del problema, definiendo claramente el objetivo o problema y cómo el aprendizaje automático puede contribuir a resolverlo parcial o totalmente. Luego, se pasa a la recolección de datos, asegurando que sean relevantes, precisos, suficientes y alineados con el problema objetivo.
#
# #### Definición del objetivo y analisis de viabilidad
# La identificación del problema en Machine Learning es el primer paso. Implica definir claramente el desafío que se requiere solventar, entendiendo de primera mano su importancia y cómo el aprendizaje automático puede ser útil.
#
# - Especificar el desafío de forma medible, es decir que se pretende predecir.
# - Identificar y reconocer el valor y el impacto que la solución proporcionará en su aplicación.
# - Asegurarse de que el problema es aplicable para técnicas de Machine Learning, es decir, si hay patrones en los datos que se pueden aprender para automatizar la toma de decisiones.
# - Determinar si se trata de un problema de clasificación, regresión, clustering, etc.
#
# #### Stakeholders
#
# Todas aquellas personas, comunidades u organizaciones que se ven involucradas o afectadas en el propósito del proyecto de forma directa o indirecta.
# identificar este tipo de tipología y gestionarlo eficazmente es crucial para asegurar que sus necesidades sean atendidas, no haya sesgos y que el proyecto sea exitoso en la medida de lo posible.
#
# #### Acondicionamiento de datos
#
# En la etapa de preparación de datos, se analizan, filtran, limpian, normalizan, completan y escalan los datos, además de manejar valores faltantes, indeterminados o atípicos, segmentarlos, transformarlos y dividirlos en conjuntos de entrenamiento y prueba. Posteriormente, en la ingeniería de modelos, se selecciona el modelo competente con la dificultad, el propósito y la capacidad de computo, se realizan ajustes de hiperparámetros y se entrena el modelo según criterios de desempeño que exige el objetivo principal.
#
# #### Evaluación, métricas e indices de desempeño
#
# Finalmente, en la evaluación del modelo, se miden métricas como precisión, recall y F1-score para determinar si el modelo es lo preciso, apto y acorde a lo esperado para ser desplegado.
#
# #### Despliegue y mantenimiento
#
# El esquema de despliegue y mantenimiento va orientado a la construcción del ecosistema de manejo de aplicaciones que gestiona el consumo y la inferencia del modelo en un orden local o en un ambiente en la nube, usando prácticas, protocolos, estándares y arquitecturas propias del desarrollo y visualización de software que garantizan la escalabilidad y optimización de recursos. Para este propósito existe la integración con bases de datos que almacenan información relevante de servicio, repositorios en la nube dedicados al almacenamiento de modelos de machine learning y controladores de versión y despliegue continuo que gestionan los cambios del modelo en producción.
#
#
# #### Metodología y conceptualización base para la implementación de modelos de regresión lineal o clasificación
# 1. Cargar, estructurar, depurar y preparar los datos de entrenamiento usando técnicas de análisis y filtrado de características
#     - Identificación y limpieza de datos irrelevantes
#     - Amputación, análisis de prioridad, transformación y normalización del conjunto.
#     - División de datos de entrenamiento y prueba (HOLD OUT)
# 2. Identificación y formulación de modelos
#     - Definición del modelo e hiperparametros de inicio
#     - Alimentación del modelo con datos de entrenamiento
#     - Predicción del modelo frente a datos de prueba
#     - Ajuste de hiperparametros
# 3. Evaluación y métricas de desempeño para el ajuste
#     - Identificación de sobre ajuste y sub ajuste con métricas de exactitud entre los segmentos de datos
#     - Validación cruzada
#     - Reporte de clasificación (Accuracy,Recall,Precision,F1-Score,support) ( si aplica )
#     - Matriz de confusión ( si aplica )
# 4. Análisis y visualización de tendencias
#     - Grafico de profundidad de arbol (max_depth: decision tree o random forest)
#     - Grafico de identificacion de profundidad versus MAE( Mean absolute error)
#     - Grafico de tendencia ROC Y Área bajo la curva (AUC) (si aplica)

# %% [markdown]
# ## 2. Selección del contexto y problema específico.
# **Objetivo:** Determinar o predecir el momento que llegada y la duración del fenómeno del niño y la niña en la ciudad de Pereira.
#
# **Contexto:** La ciudad de Pereira al igual que la mayoría del país depende de la energía hidroeléctrica, por lo que la autosuficiencia eléctrica depende en gran medida del nivel de agua en los embalses. El fenómeno del niño pone en riesgo la generación energética y posibilita el racionamientos de agua, se busca predecir el fenómeno del niño para ver que tan confiable
# La producción de leche en el Valle del Cauca es uno de los pilares más importantes dentro del sector agroindustrial de Colombia, contribuyendo significativamente a la economía local y nacional.
#
# **Identificación y Justificación:**
#
# En los últimos años, los productores de leche han enfrentado desafíos relacionados con la eficiencia en la producción, el clima y la demanda de mercado. Predecir con precisión la producción de leche permite a los ganaderos optimizar sus recursos, planificar mejor las cosechas y mejorar la rentabilidad de sus fincas.
#
# El uso de modelos predictivos en el sector agrícola mejora la eficiencia operativa y genera un impacto positivo en la seguridad alimentaria y en la sostenibilidad del sector. A nivel ambiental, el uso eficiente de recursos puede reducir el impacto negativo de la producción de leche, como el desperdicio de agua y la emisión de gases contaminantes. Además, al mejorar la eficiencia en la producción de leche, se pueden generar beneficios económicos y sociales para los pequeños y medianos productores, promoviendo el desarrollo rural en el departamento.
#
# El sector a estudiar es el Valle del Cauca, región con un gran potencial para la producción de leche, siendo un referente para el país debido a su infraestructura y a la cantidad de fincas y tierras lecheras dedicadas. El proyecto busca generar una estimación básica para efectos prácticos que tiene por objetivo determinar el aporte diario de leche en diferentes municipios del Valle del cauca, basado en factores históricos como el número de vacas en ordeño, la producción diaria y la producción promedio de cada vaca al día.
# Tipo y Manejo del Problema:
# El problema a abordar es un desarrollo de regresión para predecir el aporte diario de leche en los municipios del Valle del cauca. Se utilizarán técnicas de machine learning, específicamente modelos de regresión, para analizar datos históricos relacionados con factores que afectan directamente la producción de leche. Las fuentes de información son extraídas de datos públicos obtenidos de "datos abiertos Colombia" para el sector ganadero y agropecuario.
#
# El proyecto aplicará técnicas de ciencia de datos básico y análisis de datos exploratorio para preparar la información con la cual se entrenará el modelo.

# %%
import pandas as pd
import numpy as np
archivo_lluvia = 'datos_lluvia.csv'
datos_lluvia = pd.read_csv(archivo_lluvia)
df_lluvia = pd.DataFrame(datos_lluvia)
pd.set_option('display.max_rows', 4)
df_lluvia
# Out:
#       CodigoEstacion                  NombreEstacion       Variable  \
# 0           26135040  AEROPUERTO MATECANA [26135040]  PRECIPITACION
# 1           26135040  AEROPUERTO MATECANA [26135040]  PRECIPITACION
# ...              ...                             ...            ...
# 5412        26135040  AEROPUERTO MATECANA [26135040]  PRECIPITACION
# 5413        26135040  AEROPUERTO MATECANA [26135040]  PRECIPITACION
#
#                              Parametro             Fecha Unidad  Valor  \
# 0     Día pluviométrico (convencional)  2010-01-01 00:00     mm    0.0
# 1     Día pluviométrico (convencional)  2010-01-02 00:00     mm    0.0
# ...                                ...               ...    ...    ...
# 5412  Día pluviométrico (convencional)  2024-11-29 00:00     mm    0.7
# 5413  Día pluviométrico (convencional)  2024-11-30 00:00     mm   20.6
#
#      NivelAprobacion
# 0        En revisión
# 1        En revisión
# ...              ...
# 5412      Preliminar
# ...

# %% [markdown]
# Podemos darnos cuenta que contamos con datos desde el 2013-07-22 hasta el 2024-11-21

# %%
archivo_rsolar = 'datos_rsolar.csv'
datos_rsolar = pd.read_csv(archivo_rsolar)
df_rsolar = pd.DataFrame(datos_rsolar)
df_rsolar
# Out:
#        CodigoEstacion                  NombreEstacion   Variable  \
# 0            26125710  AEROPUERTO MATECANA [26125710]  RAD SOLAR
# 1            26125710  AEROPUERTO MATECANA [26125710]  RAD SOLAR
# ...               ...                             ...        ...
# 49141        26125710  AEROPUERTO MATECANA [26125710]  RAD SOLAR
# 49142        26125710  AEROPUERTO MATECANA [26125710]  RAD SOLAR
#
#                                      Parametro             Fecha  Unidad  \
# 0      Radiación solar global horaria VALIDADA  2014-12-08 15:00  Wh/m^2
# 1      Radiación solar global horaria VALIDADA  2014-12-08 16:00  Wh/m^2
# ...                                        ...               ...     ...
# 49141  Radiación solar global horaria VALIDADA  2022-09-11 08:00  Wh/m^2
# 49142  Radiación solar global horaria VALIDADA  2022-09-11 09:00  Wh/m^2
#
#        Valor NivelAprobacion
# 0      493.0      Definitivo
# 1       85.0      Definitivo
# ...      ...             ...
# ...

# %% [markdown]
# Hay datos de la radiación solar horaria desde 2014-12-08 hasta 2022-09-11

# %%
archivo_tseca = 'datos_temp_seca.csv'
datos_tseca = pd.read_csv(archivo_tseca)
df_tseca = pd.DataFrame(datos_tseca)
df_tseca
# Out:
#        CodigoEstacion                  NombreEstacion   Latitud   Longitud  \
# 0            26135040  AEROPUERTO MATECANA [26135040]  4.815861 -75.737222
# 1            26135040  AEROPUERTO MATECANA [26135040]  4.815861 -75.737222
# ...               ...                             ...       ...        ...
# 36476        26135040  AEROPUERTO MATECANA [26135040]  4.815861 -75.737222
# 36477        26135040  AEROPUERTO MATECANA [26135040]  4.815861 -75.737222
#
#        Altitud            Categoria  \
# 0         1342  Sinóptica Principal
# 1         1342  Sinóptica Principal
# ...        ...                  ...
# 36476     1342  Sinóptica Principal
# 36477     1342  Sinóptica Principal
#
#                                                  Entidad  \
# 0      INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1      INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# ...                                                  ...
# 36476  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# ...

# %% [markdown]
# Existen registros de la temperatura seca desde 1983-02-01 hasta 2020-01-31.
#
# ### Importancia del tipado en el análisis de datos
# En el análisis exploratorio de datos y por supuesto en la manipulación y extracción de características es importante conocer y analizar la fiabilidad en la correlación de los datos, determinando de forma anticipada el tipo de datos que se está trabajando. El tipo de datos afecta directamente la interpretación y convergencia de las correlaciones, la velocidad y procesamiento flexible.
#
# ### Detección, depurado e interpretación de datos faltantes
# Los datos faltantes en machine learning afectan significativamente el análisis y los resultados de un modelo de machine learning, generando impactos por perdida de calidad en los resultados, inconsistencia y sesgos de información y dificultad en la visualización y en las estadísticas.
#
# #### Eliminación de duplicados

# %%
df_lluvia = df_lluvia.drop_duplicates(inplace=False)
df_rsolar = df_rsolar.drop_duplicates(inplace=False)
df_tseca = df_tseca.drop_duplicates(inplace=False)

# %% [markdown]
# Hay datos de la temperatura seca del aire cada 3 horas desde 1983-02-01 hasta 2020-01-31. Se tomó este dato ya que haciendo la respectiva investigación, ya que descubrimos que este es el dato generalmente usado para los pronosticos del clima en televisión y que muestran las aplicaciones
#
# Todos los datos son tomados de la misma estación meteorológica, el aeropuerto internacional matecaña. Por lo tanto podemos ignorar muchos parámetros y enfocarnos en las variables como los campos ('VALOR') junto a sus respectivas fecha y hora para irlos clasificando
#
# #### Se extraen las columnas de fecha y valor de cada dataframe que son las que nos interesan

# %%
campos = ['Fecha', 'Valor']
diaria_lluvia = df_lluvia[campos].copy()
diaria_lluvia['Fecha'] = pd.to_datetime(diaria_lluvia['Fecha'])
diaria_lluvia.rename(columns={'Valor': 'Precipitacion'}, inplace=True)
diaria_lluvia['Fecha'] = pd.to_datetime(diaria_lluvia['Fecha']) #Convierto la fecha en tipo datetime
diaria_lluvia
# Out:
#           Fecha  Precipitacion
# 0    2010-01-01            0.0
# 1    2010-01-02            0.0
# ...         ...            ...
# 5412 2024-11-29            0.7
# 5413 2024-11-30           20.6
#
# [5414 rows x 2 columns]

# %%
new_rsolar = df_rsolar[campos].copy()
new_rsolar['Fecha'] = pd.to_datetime(new_rsolar['Fecha'])
# new_rsolar

# %%
# Como los datos de radiación solar están cada hora están por horas debemos sacar el promedio de radiación solar por dia
new_rsolar = new_rsolar[new_rsolar['Valor'] >= 5].copy() #Solo me interesan las horas reales de sol durante el dia, de noche se toman como cero
new_rsolar.loc[:, 'Dia'] = new_rsolar['Fecha'].dt.date #Extraigo la fecha sin hora en una nueva columna

diaria_rsolar = new_rsolar.groupby('Dia').agg(
    Radiacion_Promedio=('Valor', 'mean')  # Calcula el promedio diario
).reset_index()

diaria_rsolar.rename(columns={'Dia': 'Fecha'}, inplace=True)
diaria_rsolar['Fecha'] = pd.to_datetime(diaria_rsolar['Fecha']) #Convierto la fecha en tipo datetime
diaria_rsolar
# print(diaria_rsolar)
# Out:
#           Fecha  Radiacion_Promedio
# 0    2014-12-08          187.250000
# 1    2014-12-09          217.633333
# ...         ...                 ...
# 2194 2022-09-10          213.444444
# 2195 2022-09-11          192.366667
#
# [2196 rows x 2 columns]

# %%
new_tseca = df_tseca[campos].copy()
new_tseca['Fecha'] = pd.to_datetime(new_tseca['Fecha'])
# new_tseca

# %%
new_tseca.loc[:, 'Dia'] = new_tseca['Fecha'].dt.date #Extraigo la fecha sin hora en una nueva columna
new_tseca

diaria_tseca = new_tseca.groupby('Dia').agg(
    Temperatura_Promedio=('Valor', 'mean')  # Calcula el promedio diario
).reset_index()

diaria_tseca.rename(columns={'Dia': 'Fecha'}, inplace=True)
diaria_tseca['Fecha'] = pd.to_datetime(diaria_tseca['Fecha']) #Convierto la fecha en tipo datetime
diaria_tseca
# print(diaria_tseca)
# Out:
#            Fecha  Temperatura_Promedio
# 0     1983-02-01             23.200000
# 1     1983-02-02             23.333333
# ...          ...                   ...
# 12144 2020-01-30             23.500000
# 12145 2020-01-31             23.766667
#
# [12146 rows x 2 columns]

# %% [markdown]
# ## Inspección visual
# ### Análisis de los gráficos
# #### Gráficos por año

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 8)) #Tamaño del gráfico

# Grafica cada variable
plt.plot(diaria_lluvia['Fecha'], diaria_lluvia['Precipitacion'], label='Precipitación (mm)', color='blue', alpha=0.7)
plt.plot(diaria_rsolar['Fecha'], diaria_rsolar['Radiacion_Promedio'], label='Radiación Solar (Wh/m2)', color='orange', alpha=0.7)
plt.plot(diaria_tseca['Fecha'], diaria_tseca['Temperatura_Promedio'], label='Temperatura Promedio (°C)', color='green', alpha=0.7)

# Etiquetas de los ejes y titulo
plt.title(f'Comparación de Precipitación, Radiación Solar y Temperatura)', fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.tight_layout()

# Muestra el gráfico
plt.show()

# %%
def crear_rango_fechas(df, columna_fecha, frecuencia='D'):
    '''
    Crea un rango de fechas diario a partir del dataframe

    Args:
      df: DataFrame con valores de fechas.
      columna_fecha: Nombre de la columna con las fechas.
      frecuencia: Frecuencia del rango de fechas (ej: 'D' diario, 'W' semanal)

    Returns:
      Un objeto pandas.DatetimeIndex con el rango de fechas.
    '''
    f_inicio = min(df[columna_fecha])
    f_fin = max(df[columna_fecha])
    rango_fechas = pd.date_range(start = f_inicio, end = f_fin, freq = frecuencia)
    return rango_fechas

rango_fechas_lluvia = crear_rango_fechas(diaria_lluvia, 'Fecha')
rango_fechas_rsolar = crear_rango_fechas(diaria_rsolar, 'Fecha')
rango_fechas_tseca = crear_rango_fechas(diaria_tseca, 'Fecha')

# Reconstruir el dataframe con todas las fechas
lluvia_completo.rename(columns={'index': 'Fecha'}, inplace=True)

rsolar_completo = diaria_rsolar.set_index('Fecha').reindex(rango_fechas_rsolar).reset_index()
rsolar_completo.rename(columns={'index': 'Fecha'}, inplace=True)

tseca_completo = diaria_tseca.set_index('Fecha').reindex(rango_fechas_tseca).reset_index()
tseca_completo.rename(columns={'index': 'Fecha'}, inplace=True)

print(lluvia_completo)
print(rsolar_completo)
print(tseca_completo)

# print(lluvia_completo.isnull().sum())
# print(rsolar_completo.isnull().sum())
# print(tseca_completo.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 23
#      20 rango_fechas_tseca = crear_rango_fechas(diaria_tseca, 'Fecha')
#      22 # Reconstruir el dataframe con todas las fechas
# ---> 23 lluvia_completo.rename(columns={'index': 'Fecha'}, inplace=True)
#      25 rsolar_completo = diaria_rsolar.set_index('Fecha').reindex(rango_fechas_rsolar).reset_index()
#      26 rsolar_completo.rename(columns={'index': 'Fecha'}, inplace=True)
#
# NameError: name 'lluvia_completo' is not defined

# %%
# Manejo de datos faltantes mediante la media de cada mes en función del mismo periodo de tiempo de años diferentes
lluvia_completo['Precipitacion'] = lluvia_completo['Precipitacion'].fillna(
    lluvia_completo.groupby(tseca_completo['Fecha'].dt.month)['Precipitacion'].transform('mean')
)

rsolar_completo['Radiacion_Promedio'] = rsolar_completo['Radiacion_Promedio'].fillna(
    rsolar_completo.groupby(rsolar_completo['Fecha'].dt.month)['Radiacion_Promedio'].transform('mean')
)
rsolar_completo['Radiacion_Promedio'] = rsolar_completo['Radiacion_Promedio'].interpolate(method='linear')

tseca_completo['Temperatura_Promedio'] = tseca_completo['Temperatura_Promedio'].fillna(
    tseca_completo.groupby(tseca_completo['Fecha'].dt.month)['Temperatura_Promedio'].transform('mean')
)

# %%
import matplotlib.pyplot as plt

# Gráfico de líneas
fecha_inicio = '2014-12-08'
# fecha_inicio = '2018-10-01'
fecha_inicio = pd.to_datetime(fecha_inicio) 
# fecha_fin = ''

# Sólo gráficaremos después de fecha_inicio
lluvia_filtered = diaria_lluvia[diaria_lluvia['Fecha'] >= fecha_inicio].copy()
rsolar_filtered = diaria_rsolar[diaria_rsolar['Fecha'] >= fecha_inicio].copy()
tseca_filtered = diaria_tseca[diaria_tseca['Fecha'] >= fecha_inicio].copy()


plt.figure(figsize=(15, 8)) #Tamaño del gráfico

# Grafica cada variable
plt.plot(lluvia_filtered['Fecha'], lluvia_filtered['Precipitacion'], label='Precipitación (mm)', color='blue', alpha=0.7)
plt.plot(rsolar_filtered['Fecha'], rsolar_filtered['Radiacion_Promedio'], label='Radiación Solar (Wh/m2)', color='orange', alpha=0.7)
plt.plot(tseca_filtered['Fecha'], tseca_filtered['Temperatura_Promedio'], label='Temperatura Promedio (°C)', color='green', alpha=0.7)

# Etiquetas de los ejes y titulo
plt.title(f'Comparación de Precipitación, Radiación Solar y Temperatura ({fecha_inicio.year} en adelante)', fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.tight_layout()

# Muestra el gráfico
plt.show()

# %%
def crear_rango_fechas(df, columna_fecha, frecuencia='D'):
    '''
    Crea un rango de fechas diario a partir del dataframe

    Args:
      df: DataFrame con valores de fechas.
      columna_fecha: Nombre de la columna con las fechas.
      frecuencia: Frecuencia del rango de fechas (ej: 'D' diario, 'W' semanal)

    Returns:
      Un objeto pandas.DatetimeIndex con el rango de fechas.
    '''
    f_inicio = min(df[columna_fecha])
    f_fin = max(df[columna_fecha])
    rango_fechas = pd.date_range(start = f_inicio, end = f_fin, freq = frecuencia)
    return rango_fechas

rango_fechas_lluvia = crear_rango_fechas(lluvia_filtered, 'Fecha')
rango_fechas_rsolar = crear_rango_fechas(rsolar_filtered, 'Fecha')
rango_fechas_tseca = crear_rango_fechas(tseca_filtered, 'Fecha')

# Reconstruir el dataframe con todas las fechas
lluvia_completo = lluvia_filtered.set_index('Fecha').reindex(rango_fechas_lluvia).reset_index()
lluvia_completo.rename(columns={'index': 'Fecha'}, inplace=True)

rsolar_completo = rsolar_filtered.set_index('Fecha').reindex(rango_fechas_rsolar).reset_index()
rsolar_completo.rename(columns={'index': 'Fecha'}, inplace=True)

tseca_completo = tseca_filtered.set_index('Fecha').reindex(rango_fechas_tseca).reset_index()
tseca_completo.rename(columns={'index': 'Fecha'}, inplace=True)

print(lluvia_completo)
print(rsolar_completo)
print(tseca_completo)

# print(lluvia_completo.isnull().sum())
# print(rsolar_completo.isnull().sum())
# print(tseca_completo.isnull().sum())

# %% [markdown]
# **Datos faltantes**
# Precipitacion: 34.
# Radiacion_Promedio: 639.
# Temperatura_Promedio: 361.
#
# ### Tratamiento de datos ausentes y anomalias
# El manejo de datos faltantes es importante para que los valores nulos o vacíos no afecten la correlación de las métricas estadísticas, la interpretación, el análisis descriptivo y el desempeño del modelo de machine learning.
#
# - Z-Score
#     - z= abs((x-media)/std)
# - Media
# - Mediana

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose

# # # Ejemplo con radiación solar
# # decomposed = seasonal_decompose(lluvia_filtered['Precipitacion'], model='additive', period=365)
# # decomposed.plot()

# import seaborn as sns
# import matplotlib.pyplot as plt

# # Correlación con Pearson
# correlacion = lluvia_filtered.corr(method='pearson')
# sns.heatmap(correlacion, annot=True, cmap='coolwarm')
# plt.title('Mapa de calor de la correlación')
# plt.show()

# %%
# Manejo de datos faltantes mediante la media de cada mes en función del mismo periodo de tiempo de años diferentes
# rsolar_completo['Radiacion_Promedio'] = rsolar_completo['Radiacion_Promedio'].fillna(
#     rsolar_completo.groupby(rsolar_completo['Fecha'].dt.month)['Radiacion_Promedio'].transform('mean')
# )
# rsolar_completo['Radiacion_Promedio'] = rsolar_completo['Radiacion_Promedio'].interpolate(method='linear')

# tseca_completo['Temperatura_Promedio'] = tseca_completo['Temperatura_Promedio'].fillna(
#     tseca_completo.groupby(tseca_completo['Fecha'].dt.month)['Temperatura_Promedio'].transform('mean')
# )

# lluvia_completo['Precipitacion'] = lluvia_completo['Precipitacion'].interpolate(method='linear')

# Imputación para precipitación (lluvia)
lluvia_completo['Precipitacion'] = lluvia_completo['Precipitacion'].fillna(
    lluvia_completo.groupby(lluvia_completo['Fecha'].dt.isocalendar().week)['Precipitacion'].transform('mean')
)

# Imputación para radiación solar
rsolar_completo['Radiacion_Promedio'] = rsolar_completo['Radiacion_Promedio'].fillna(
    rsolar_completo.groupby(rsolar_completo['Fecha'].dt.isocalendar().week)['Radiacion_Promedio'].transform('mean')
)

# Imputación para temperatura
tseca_completo['Temperatura_Promedio'] = tseca_completo['Temperatura_Promedio'].fillna(
    tseca_completo.groupby(tseca_completo['Fecha'].dt.isocalendar().week)['Temperatura_Promedio'].transform('mean')
)

print(lluvia_completo)
print(rsolar_completo)
print(tseca_completo)
# lluvia_completo.info()

# %%
# Rango de años para las gráficas
years = range(2014, 2024)

# Crear una figura con 10 subplots (2 columnas x 5 filas)
fig, axes = plt.subplots(5, 2, figsize=(15, 20))
fig.tight_layout(pad=5.0)

# Iterar sobre los años y los ejes correspondientes
for i, (year, ax) in enumerate(zip(years, axes.flatten()), start=1):
    # Filtrar los datos por el año actual
    year_lluvia = lluvia_completo[lluvia_completo['Fecha'].dt.year == year]
    year_rsolar = rsolar_completo[rsolar_completo['Fecha'].dt.year == year]
    year_tseca = tseca_completo[tseca_completo['Fecha'].dt.year == year]
    
    # Graficar en el subplot correspondiente
    ax.plot(year_lluvia['Fecha'], year_lluvia['Precipitacion'], label='Precipitación', color='blue', alpha=0.7)
    ax.plot(year_rsolar['Fecha'], year_rsolar['Radiacion_Promedio'], label='Radiación Solar', color='orange', alpha=0.7)
    ax.plot(year_tseca['Fecha'], year_tseca['Temperatura_Promedio'], label='Temperatura', color='green', alpha=0.7)
    # ax.set_ylim(0,1)
    
    # Configurar título y ejes
    ax.set_title(f'Año {year}', fontsize=10)
    ax.set_xlabel('Fecha', fontsize=8)
    ax.set_ylabel('Valor', fontsize=8)
    ax.tick_params(axis='both', labelsize=8)
    ax.grid(True)

# Añadir leyenda al primer subplot
axes[0, 0].legend(fontsize=6)

# Mostrar la gráfica
plt.show()

# %%
plt.figure(figsize=(15, 8)) #Tamaño del gráfico

# Grafica cada variable
plt.plot(lluvia_completo['Fecha'], lluvia_completo['Precipitacion'], label='Precipitación (mm)', color='blue', alpha=0.7)
plt.plot(rsolar_completo['Fecha'], rsolar_completo['Radiacion_Promedio'], label='Radiación Solar (Wh/m2)', color='orange', alpha=0.7)
plt.plot(tseca_completo['Fecha'], tseca_completo['Temperatura_Promedio'], label='Temperatura Promedio (°C)', color='green', alpha=0.7)

# Etiquetas de los ejes y titulo
plt.title(f'Comparación de Precipitación, Radiación Solar y Temperatura ({fecha_inicio.year} en adelante)', fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.tight_layout()

# Muestra el gráfico
plt.show()

# %% [markdown]
# El tamaño de las gráficas no es muy analizable, por lo que lo mejor sería escalarlas

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler
# Normalización
scaler = MinMaxScaler()
# scaler = RobustScaler()


# Normaliza cada dataset por separado
lluvia_completo.loc[:,'Precipitacion_Normalizada'] = scaler.fit_transform(lluvia_completo[['Precipitacion']])
rsolar_completo.loc[:,'Radiacion_Normalizada'] = scaler.fit_transform(rsolar_completo[['Radiacion_Promedio']])
tseca_completo.loc[:,'Temperatura_Normalizada'] = scaler.fit_transform(tseca_completo[['Temperatura_Promedio']])

plt.figure(figsize=(14, 6))

plt.plot(lluvia_completo['Fecha'], lluvia_completo['Precipitacion_Normalizada'], label='Precipitación (Normalizada)', color='blue', alpha=0.7)
plt.plot(rsolar_completo['Fecha'], rsolar_completo['Radiacion_Normalizada'], label='Radiación Solar (Normalizada)', color='orange', alpha=0.7)
plt.plot(tseca_completo['Fecha'], tseca_completo['Temperatura_Normalizada'], label='Temperatura (Normalizada)', color='green', alpha=0.7)

plt.title(f'Comparación Normalizada de Precipitación, Radiación Solar y Temperatura después ({fecha_inicio.date()} en adelante)', fontsize=14)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Valor Normalizado', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Para poder visualizar mejor los datos y tener una mejor consistencia, se opta por graficar de forma anual y que los datos se recopilen de forma semanal.

# %%
#Para la lluvia
lluvia_completo.loc[:, 'Semana'] = ((lluvia_completo['Fecha'] - pd.Timestamp(fecha_inicio)).dt.days // 7) # Cada semana tendrá un número único
semanal_lluvia = lluvia_completo.groupby('Semana')['Precipitacion_Normalizada'].mean().reset_index() # Agrupamos número de semana y promedio
semanal_lluvia['Fecha_Inicial'] = pd.to_datetime(fecha_inicio) + pd.to_timedelta(semanal_lluvia['Semana'] * 7, unit='d') # número de la semana
semanal_lluvia.rename(columns={'Precipitacion_Normalizada': 'Promedio_Semanal'}, inplace=True) #renombrando columnas
# print(semanal_lluvia)

#Para la radiación solar
rsolar_completo.loc[:, 'Semana'] = ((rsolar_completo['Fecha'] - pd.Timestamp(fecha_inicio)).dt.days // 7)
semanal_rsolar = rsolar_completo.groupby('Semana')['Radiacion_Normalizada'].mean().reset_index()
semanal_rsolar['Fecha_Inicial'] = pd.to_datetime(fecha_inicio) + pd.to_timedelta(semanal_rsolar['Semana'] * 7, unit='d')
semanal_rsolar.rename(columns={'Radiacion_Normalizada': 'Promedio_Semanal'}, inplace=True)
# print(semanal_rsolar)

#Para la radiación solar
tseca_completo.loc[:, 'Semana'] = ((tseca_completo['Fecha'] - pd.Timestamp(fecha_inicio)).dt.days // 7)
semanal_tseca = tseca_completo.groupby('Semana')['Temperatura_Normalizada'].mean().reset_index()
semanal_tseca['Fecha_Inicial'] = pd.to_datetime(fecha_inicio) + pd.to_timedelta(semanal_tseca['Semana'] * 7, unit='d')
semanal_tseca.rename(columns={'Temperatura_Normalizada': 'Promedio_Semanal'}, inplace=True)
print(semanal_tseca)

plt.figure(figsize=(14, 6))
plt.plot(semanal_lluvia['Fecha_Inicial'], semanal_lluvia['Promedio_Semanal'], label='Precipitación (Normalizada)', color='blue', alpha=0.7)
plt.plot(semanal_rsolar['Fecha_Inicial'], semanal_rsolar['Promedio_Semanal'], label='Radiación Solar (Normalizada)', color='orange', alpha=0.7)
plt.plot(semanal_tseca['Fecha_Inicial'], semanal_tseca['Promedio_Semanal'], label='Temperatura (Normalizada)', color='green', alpha=0.7)
plt.title(f'Comparación Normalizada de Precipitación, Radiación Solar y Temperatura semanal ({fecha_inicio.date()} en adelante)', fontsize=14)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Valor Normalizado', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Filtrar por año especifico

# %%
# Rango de años para las gráficas
years = range(2014, 2024)

# Crear una figura con 10 subplots (2 columnas x 5 filas)
fig, axes = plt.subplots(5, 2, figsize=(15, 20))
fig.tight_layout(pad=5.0)

# Iterar sobre los años y los ejes correspondientes
for i, (year, ax) in enumerate(zip(years, axes.flatten()), start=1):
    # Filtrar los datos por el año actual
    year_lluvia = semanal_lluvia[semanal_lluvia['Fecha_Inicial'].dt.year == year]
    year_rsolar = semanal_rsolar[semanal_rsolar['Fecha_Inicial'].dt.year == year]
    year_tseca = semanal_tseca[semanal_tseca['Fecha_Inicial'].dt.year == year]
    
    # Graficar en el subplot correspondiente
    ax.plot(year_lluvia['Fecha_Inicial'], year_lluvia['Promedio_Semanal'], label='Precipitación', color='blue', alpha=0.7)
    ax.plot(year_rsolar['Fecha_Inicial'], year_rsolar['Promedio_Semanal'], label='Radiación Solar', color='orange', alpha=0.7)
    ax.plot(year_tseca['Fecha_Inicial'], year_tseca['Promedio_Semanal'], label='Temperatura', color='green', alpha=0.7)
    ax.set_ylim(0,1)
    
    # Configurar título y ejes
    ax.set_title(f'Año {year}', fontsize=10)
    ax.set_xlabel('Fecha', fontsize=8)
    ax.set_ylabel('Valor', fontsize=8)
    ax.tick_params(axis='both', labelsize=8)
    ax.grid(True)

# Añadir leyenda al primer subplot
axes[0, 0].legend(fontsize=6)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ## Análisis Univariado
# Se emplea para comprender la distribución, tendencia y dispersión de una variable, para eso se hará uso del histograma o grafico de densidad y la estadística descriptiva común para analizar detenidamente la variable en cuestión
# ### 1. Validación de Distribución Normal
# Este paso se usa para corroborar si los datos de una variable siguen una distribución normal (gaussiana).
#
# #### Histograma
# Leyendo los histogramas nos damos cuenta de que mientras la radiación solar y la temperatura tienen una distribución normal, la pluviosidad tiene una distribución sesgada positivamente.

# %%
import seaborn as sns
sns.histplot(semanal_lluvia['Promedio_Semanal'],kde=True)
sns.histplot(semanal_rsolar['Promedio_Semanal'],kde=True)
sns.histplot(semanal_tseca['Promedio_Semanal'],kde=True)

# %% [markdown]
# #### Dispersión de los datos

# %%
fig = plt.figure(figsize = (15, 6))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)
ax1.set_title('Precipitación')
ax1.plot(semanal_lluvia['Promedio_Semanal'], linewidth = 0, marker = 'o', color = 'blue', markersize = 6)
ax1.set_ylim(0,1)
ax2.set_title('Radiación solar')
ax2.plot(semanal_rsolar['Promedio_Semanal'], linewidth = 0, marker = 'o', color = 'orange', markersize = 6)
ax2.set_ylim(0,1)
ax3.set_title('Temperatura')
ax3.plot(semanal_tseca['Promedio_Semanal'], linewidth = 0, marker = 'o', color = 'green', markersize = 6)
ax3.set_ylim(0,1)
plt.show()

# %% [markdown]
# #### Gráfico Q-Q (Quantile-Quantile)
# Compara los cuantiles de los datos en una distribución normal teórica. Los puntos deben alinearse a lo largo de una línea diagonal.

# %%
import scipy.stats as stats
# Q-Q plot para las tres variable
fig, axs = plt.subplots(1, 3, figsize=(15, 6))
stats.probplot(semanal_lluvia['Promedio_Semanal'], dist="norm", plot=axs[0])
axs[0].set_title('Q-Q Precipitación')
# axs[0].set_ylim(0,1)

stats.probplot(semanal_rsolar['Promedio_Semanal'], dist="norm", plot=axs[1])
axs[1].set_title('Q-Q Radiación Solar')
# axs[1].set_ylim(0,1)

stats.probplot(semanal_tseca['Promedio_Semanal'], dist="norm", plot=axs[2])
axs[2].set_title('Q-Q Temperatura')
# axs[2].set_ylim(0,1)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Pruebas de Normalidad
# la prueba de Shapiro-Wilk o la prueba de Kolmogorov-Smirnov pueden determinar si los datos se desvían significativamente de la normalidad.

# %%
from scipy.stats import shapiro, kstest

# Shapiro-Wilk Test
print("Shapiro-Wilk Test:")
for var, data in zip(['Precipitación', 'Radiación Solar', 'Temperatura'], 
                     [semanal_lluvia, semanal_rsolar, semanal_tseca]):
    stat, p_value = shapiro(data['Promedio_Semanal'])
    print(f"{var}: Estadístico = {stat:.4f}, p-value = {p_value:.4f}")

# Kolmogorov-Smirnov Test
print("\nKolmogorov-Smirnov Test:")
for var, data in zip(['Precipitación', 'Radiación Solar', 'Temperatura'], 
                     [semanal_lluvia, semanal_rsolar, semanal_tseca]):
    stat, p_value = kstest(data['Promedio_Semanal'], 'norm', 
                           args=(data['Promedio_Semanal'].mean(), data['Promedio_Semanal'].std()))
    print(f"{var}: Estadístico = {stat:.4f}, p-value = {p_value:.4f}")

# %% [markdown]
# Los datos *'p-value' < 0.05* indican que los datos no siguen una distribución normal
#
# ### 2. Estadísticas Descriptivas
# Las estadísticas descriptivas proporcionan un resumen numérico de las características principales de una variable
#
# **Precipitación**

# %%
from scipy.stats import skew, kurtosis

print('Media:', semanal_lluvia['Promedio_Semanal'].mean())
print('Mediana:', semanal_lluvia['Promedio_Semanal'].median())
print('Moda:', semanal_lluvia['Promedio_Semanal'].mode())
print('Desviación estandar:', semanal_lluvia['Promedio_Semanal'].std())
print('Varianza:', semanal_lluvia['Promedio_Semanal'].var())

q1 = semanal_lluvia['Promedio_Semanal'].quantile(0.25)
q3 = semanal_lluvia['Promedio_Semanal'].quantile(0.75)
iqr = q3 - q1
print('Rango intercuartilico (dispersion central):',iqr)

asimetria = skew(semanal_lluvia['Promedio_Semanal'])
# print('Coeficiente de asimetria de:',asimetria,'---> Tiene un sesgo o asimetria positiva hacia la derecha')

curtosis = kurtosis(semanal_lluvia['Promedio_Semanal'], fisher=True)
# print('Curtosis:',curtosis,'---> Es mas apuntada que una normal')

# %% [markdown]
# **Radiación solar**

# %%
print('Media:', semanal_rsolar['Promedio_Semanal'].mean())
print('Mediana:', semanal_rsolar['Promedio_Semanal'].median())
print('Moda:', semanal_rsolar['Promedio_Semanal'].mode())
print('Desviación estandar:', semanal_rsolar['Promedio_Semanal'].std())
print('Varianza:', semanal_rsolar['Promedio_Semanal'].var())

q1 = semanal_rsolar['Promedio_Semanal'].quantile(0.25)
q3 = semanal_rsolar['Promedio_Semanal'].quantile(0.75)
iqr = q3 - q1
print('Rango intercuartilico (dispersion central):',iqr)

asimetria = skew(semanal_rsolar['Promedio_Semanal'])
# print('Coeficiente de asimetria de:',asimetria,'---> Tiene un sesgo o asimetria positiva hacia la derecha')

curtosis = kurtosis(semanal_rsolar['Promedio_Semanal'], fisher=True)
# print('Curtosis:',curtosis,'---> Es mas apuntada que una normal')

# %% [markdown]
# **Temperatura**

# %%
print('Media:', semanal_tseca['Promedio_Semanal'].mean())
print('Mediana:', semanal_tseca['Promedio_Semanal'].median())
print('Moda:', semanal_tseca['Promedio_Semanal'].mode())
print('Desviación estandar:', semanal_tseca['Promedio_Semanal'].std())
print('Varianza:', semanal_tseca['Promedio_Semanal'].var())

q1 = semanal_tseca['Promedio_Semanal'].quantile(0.25)
q3 = semanal_tseca['Promedio_Semanal'].quantile(0.75)
iqr = q3 - q1
print('Rango intercuartilico (dispersion central):',iqr)

asimetria = skew(semanal_tseca['Promedio_Semanal'])
# print('Coeficiente de asimetria de:',asimetria,'---> Tiene un sesgo o asimetria positiva hacia la derecha')

curtosis = kurtosis(semanal_tseca['Promedio_Semanal'], fisher=True)
# print('Curtosis:',curtosis,'---> Es mas apuntada que una normal')

# %% [markdown]
# ## Análisis Bivariado: Correlación
# El análisis bivariado se enfoca en estudiar la relación entre dos variables para entender cómo una variable puede afectar o estar relacionada con otra. La correlación es de los métodos mas utilizados y el que implementaremos para este proyecto.

# %%
# Para hallar las medidas de correlación debemos ajustar todos los dataframe de una fecha que hayan datos de los 3
# hasta la fecha que termine el primero de los 3
f_inicio = '2014-12-08'
f_inicio = pd.to_datetime(f_inicio)
f_fin = '2020-01-31'
f_fin = pd.to_datetime(f_fin)

unificado_lluvia = semanal_lluvia[(semanal_lluvia['Fecha_Inicial'] >= f_inicio) & (semanal_lluvia['Fecha_Inicial'] <= f_fin)].copy()
print(unificado_lluvia)
unificado_rsolar = semanal_rsolar[(semanal_rsolar['Fecha_Inicial'] >= f_inicio) & (semanal_rsolar['Fecha_Inicial'] <= f_fin)].copy()
print(unificado_rsolar)
unificado_tseca = semanal_tseca[(semanal_tseca['Fecha_Inicial'] >= f_inicio) & (semanal_tseca['Fecha_Inicial'] <= f_fin)].copy()
print(unificado_tseca)

# %% [markdown]
# ### Medidas de Correlación

# %%
fig = plt.figure(figsize=(15, 6))

# Gráfico de dispersión entre lluvia y radiación solar
ax1 = fig.add_subplot(1, 3, 1)
ax1.scatter(unificado_lluvia['Promedio_Semanal'], unificado_rsolar['Promedio_Semanal'], color='blue', alpha=0.7)
ax1.set_title('Lluvia vs Radiación Solar')
ax1.set_xlabel('Lluvia (Promedio Semanal)')
ax1.set_ylabel('Radiación Solar (Promedio Semanal)')

# Gráfico de dispersión entre radiación solar y temperatura
ax2 = fig.add_subplot(1, 3, 2)
ax2.scatter(unificado_rsolar['Promedio_Semanal'], unificado_tseca['Promedio_Semanal'], color='orange', alpha=0.7)
ax2.set_title('Radiación Solar vs Temperatura')
ax2.set_xlabel('Radiación Solar (Promedio Semanal)')
ax2.set_ylabel('Temperatura (Promedio Semanal)')

# Gráfico de dispersión entre lluvia y temperatura
ax3 = fig.add_subplot(1, 3, 3)
ax3.scatter(unificado_lluvia['Promedio_Semanal'], unificado_tseca['Promedio_Semanal'], color='green', alpha=0.7)
ax3.set_title('Lluvia vs Temperatura')
ax3.set_xlabel('Lluvia (Promedio Semanal)')
ax3.set_ylabel('Temperatura (Promedio Semanal)')

plt.tight_layout()
plt.show()

# %%
# Calculamos los coeficientes de correlación de Pearson
correlacion_pearson = unificado_lluvia['Promedio_Semanal'].corr(unificado_rsolar['Promedio_Semanal'])
print(f"Correlación Pearson entre lluvia y radiación solar: {correlacion_pearson:.2f}")

correlacion_pearson = unificado_rsolar['Promedio_Semanal'].corr(unificado_tseca['Promedio_Semanal'])
print(f"Correlación Pearson entre radiación solar y temperatura: {correlacion_pearson:.2f}")

# Calculamos los coeficientes de Spearman (opcional si no son relaciones lineales)
correlacion_spearman = unificado_lluvia['Promedio_Semanal'].corr(unificado_rsolar['Promedio_Semanal'], method='spearman')
print(f"Correlación Spearman entre lluvia y radiación solar: {correlacion_spearman:.2f}")

correlacion_spearman = unificado_rsolar['Promedio_Semanal'].corr(unificado_tseca['Promedio_Semanal'], method='spearman')
print(f"Correlación Spearman entre radiación solar y temperatura: {correlacion_spearman:.2f}")

# %% [markdown]
# La correlación entre los datos es menor a 0.5 lo que significa que si existe pero es una correlación baja.

# %% [markdown]
# ## Análisis Multivariado: Análisis de Componentes Principales (PCA)
# El análisis multivariado se utiliza para entender relaciones entre múltiples variables y reducir la complejidad de los datos. Uno de los métodos más importantes en el análisis multivariado es el Análisis de Componentes Principales (PCA)
#
# - Componente Principal 1 (PC1): Captura la mayor parte de la varianza en los datos.
# - Componente Principal 2 (PC2): Captura la siguiente mayor parte de la varianza, y es ortogonal a PC1.
# - Componente N (PCN): Cada componente adicional captura una menor proporción de la varianza restante.
#
# Proceso de PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

# Combinamos las columnas relevantes en un único DataFrame para el PCA
datos_pca = pd.DataFrame({
    'Lluvia': unificado_lluvia['Promedio_Semanal'],
    'Radiación Solar': unificado_rsolar['Promedio_Semanal'],
    'Temperatura': unificado_tseca['Promedio_Semanal']
})

# Estandarizamos los datos
scaler = StandardScaler()
datos_estandarizados = scaler.fit_transform(datos_pca)

# %%
# Calculamos la matriz de covarianza
matriz_covarianza = pd.DataFrame(datos_estandarizados).cov()
print("Matriz de Covarianza:\n", matriz_covarianza)

# %%
# Aplicamos PCA
pca = PCA(n_components=3)  # Número de componentes principales
pca.fit(datos_estandarizados)
datos_transformados = pca.transform(datos_estandarizados)

# Imprimimos la varianza explicada por cada componente
print("Varianza explicada por cada componente principal:")
print(pca.explained_variance_ratio_)

# %%
# Visualizamos los datos proyectados en los primeros dos componentes principales
plt.figure(figsize=(8, 6))
plt.scatter(datos_transformados[:, 0], datos_transformados[:, 1], c='blue', edgecolor='k', s=50)
plt.title('Proyección en el Espacio de Componentes Principales')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.grid()
plt.show()
