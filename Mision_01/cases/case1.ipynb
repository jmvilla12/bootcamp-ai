# %% [markdown]
# # Caso 1
# Fecha: 23/11/2024
# ### Integrantes
# - Jose Manuel Villa Romero
# - Sebastian Vasquez Grajales
# - Juan Camilo Castaño Marulanda
#
# ## 1. Búsqueda de Conjuntos de Datos:
# Encontramos un dataset en la página de datos abiertos Colombia, esta habla sobre la prestación del servicio eléctrico en las zonas no interconectadas al sistema nacional.
# DataSet: [Link](https://www.datos.gov.co/Minas-y-Energ-a/Estado-de-la-prestaci-n-del-servicio-de-energ-a-en/3ebi-d83g/about_data)

# %%
import pandas as pd
archivo_csv = 'zonas_no_interconectadas.csv'
datos_csv = pd.read_csv(archivo_csv)

# %%
df = pd.DataFrame(datos_csv)
df.columns
# Out:
# Index(['ID DEPATAMENTO', 'DEPARTAMENTO', 'ID MUNICIPIO', 'MUNICIPIO',
#        'ID LOCALIDAD', 'LOCALIDAD', 'AÑO SERVICIO', 'MES SERVICIO',
#        'ENERGÍA ACTIVA', 'ENERGÍA REACTIVA', 'POTENCIA MÁXIMA',
#        'DÍA DE DEMANDA MÁXIMA', 'FECHA DE DEMANDA MÁXIMA',
#        'PROMEDIO DIARIO EN HORAS'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID DEPATAMENTO                              DEPARTAMENTO  ID MUNICIPIO  \
# 0              91                                  AMAZONAS         91540
# 1              91                                  AMAZONAS         91798
# 2               5                                 ANTIOQUIA          5873
# 3              88  ARCHIPIÉLAGO DE SAN ANDRÉS y PROVIDENCIA         88564
# 4              13                                   BOLÍVAR         13001
#
#              MUNICIPIO  ID LOCALIDAD  \
# 0        PUERTO NARIÑO      91540000
# 1       TARAPACA (ANM)      91798000
# 2     VIGÍA DEL FUERTE       5873010
# 3          PROVIDENCIA      88564000
# 4  CARTAGENA DE INDIAS      13001007
#
#                                            LOCALIDAD  AÑO SERVICIO  \
# 0           PUERTO NARIÑO (PUERTO NARIÑO - AMAZONAS)          2024
# 1               TARAPACA (TARAPACA (ANM) - AMAZONAS)          2024
# 2     LA PLAYA MURRI  (VIGÍA DEL FUERTE - ANTIOQUIA)          2024
# ...

# %% [markdown]
# ## 2. Identificación del problema:
# **Problema:** Prestación del servicio de energía eléctrica en zonas no interconectadas a la red eléctrica nacional, lo implica una irregularidad en la prestación del servicio, afección a la calidad de vda y productividad de las comunidades.
#
# **Stakeholders:**
# - **Comunidades locales:** Afectadas por la irregularidad del servicio.
# - **Gobierno:** Responsables de garantizar la calidad y cobertura del servicio.
# - **Empresas energéticas:** Encargadas de implementar las soluciones.
# - **ONGs:** Pueden dar apoyo en proyectos de energías limpias.
#
# ## 3. Propuesta de Solución con Machine Learning:
# **Propuesta:** Predecir las horas de servicio energético promedio diario para priorizar mejoras en infraestructura y recursos.
# - **Regresión:** Se podría llegar a generar el promedio de horas diarias utilizando variables como energía activa, reactiva, potencia máxima, además de filtrar los datos por departamento o municipio.
# - **Clustering** (más dificil de implementar)**:** Agrupar localidades según caracterísitcas energéticas para priorizar intervenciones.
